# %%
import example_graphs as exgr
import cluster_refinement as refinement
import spectral_embedding as spe
import preprocessing as prcs
import deformations as deform
import visual_aids as vis

import networkx as nx
import matplotlib.pyplot as plt

# %%
H = exgr.test_graph(30)
vis.draw(H)

# %%
H = prcs.contract_deg2(H)
vis.draw(H)

# %%
spe.fast_eigen_decomp(H,50)
# Out:
# choosing from 20 SM or LM eigenvals
# calculating gaps between normalized laplacian eigenvalues
# std gaps 0.014611373478437805
# max gap 0.06595397530073999
# number of similar gaps, including largest 2
# calculating gaps between normalized signless laplacian eigenvalues
# std gaps 0.1208442488764675
# max gap -0.008335531985026678
# number of similar gaps, including largest 18
# {'size': 29,
#  'spectral_radius': np.float64(9.487661529922605),
#  'Perron cluster': array([[-0.1860521 ],
#         [-0.21483446],
#         [-0.20568834],
#         [-0.19611614],
#         [-0.16408253],
#         [-0.20568834],
#         [-0.16408253],
#         [-0.1860521 ],
#         [-0.13867505],
#         [-0.1860521 ],
#         [-0.15191091],
#         [-0.1860521 ],
#         [-0.20568834],
#         [-0.15191091],
#         [-0.19611614],
#         [-0.19611614],
#         [-0.20568834],
#         [-0.20568834],
#         [-0.21483446],
#         [-0.1754116 ],
#         [-0.1860521 ],
# ...
